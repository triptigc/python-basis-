# %% [markdown]
# ## 1. Simple arithmetic calculator

# %%
number1=float(input("Enter first number:"))
number2=float(input("Enter second number:"))
operator=input("Select an operator (+ - * /):" )

if operator=="+":
 result=number1+number2
 print(round(result,2))

if operator=="-":
 result=number1-number2
 print(round(result,2))


if operator=="*":
 result=number1*number2
 print(round(result,2))


if operator=="/":
 result=number1/number2
 print(round(result,2))
# Out:
# 123.99

# %% [markdown]
# ## 2. Weight Converter

# %%
weight=float(input("Enter your weight: "))
convert=input("Convert to (kg or lbs): ")

if convert=="kg":
  weight=weight*2.20
  print (f"Your weight: {round(weight,2)} {convert}")
  convert="lbs."

elif convert =="lbs":
  weight=weight/2.20
  print (f"Your weight: {round(weight,2)} {convert}")
  convert="kg."

else :
 print(f"{convert} invalid conversion")

print(f"Your converted  weight is: {weight} {convert}")
# Out:
# Your weight: 880.0 kg
# Your converted  weight is: 880.0000000000001 lbs.

# %% [markdown]
# ## 3. Temperature conversion program

# %%
unit=input("Enter the unit of temperature: (c or f)")
temp=float(input("Enter the current temperature: "))

if unit == "c":
  temp=(temp*1.8+32)
  unit="F."
  print(f"converted temp is: {temp} {unit}")

elif unit=="f":
  temp=(temp-32/1.8)
  unit="c."
  print(f"converted temp is: {temp} {unit}")

else:
  print(f"invalid {temp} {unit}")
# Out:
# converted temp is: 492.8 F.

# %% [markdown]
# ## 4. Email slicer program

# %%
email=input("Enter your email: ")
index=email.index("@")

username=email[:index]
domain=email[index+1:]

print(f"your username is {username} and domain name is {domain}")
# Out:
# your username is triptiee and domain name is gmail.com

# %% [markdown]
# ## 5. Compund Interest Calculator

# %%
principle=0 
Rate=0
time=0

while principle<=0:
  principle=float(input("Enter the principle: "))
  if principle<=0:
    print("Invalid principle")

while Rate<=0:
  Rate=float(input("Enter the Rate: "))
  if Rate<=0:
    print("Invalid Rate")

while time<=0:
  time=int(input("Enter the time period: "))
  if time<=0:
    print("Invalid time period.")

total=principle*pow((1+Rate/100),time)
print(f"Your total value will be {total}.  ")
# Out:
# Your total value will be 52020.0.

# %% [markdown]
# ## 6. Countdown Timer

# %%
import time 

set_time=int(input("Enter the time:"))

for x in reversed(range(0,set_time)):
 seconds=x%60
 minutes=int(x/60)%60
 hours=int(x/3600)
 print(f"{hours:02}:{minutes:02}:{seconds:02}") #using format specifier 
 time.sleep(1) # Time duration for another number to pop up 

print("Time's up!")
# Out:
# 01:00:04
# 01:00:03
# 01:00:02
# 01:00:01
# 01:00:00
# 00:59:59
# 00:59:58
# 00:59:57
# 00:59:56
# 00:59:55
# 00:59:54
# 00:59:53
# 00:59:52
# 00:59:51
# 00:59:50
# 00:59:49
# 00:59:48
# 00:59:47
# 00:59:46
# 00:59:45
# 00:59:44
# 00:59:43
# 00:59:42
# 00:59:41
# 00:59:40
# 00:59:39
# 00:59:38
# 00:59:37
# 00:59:36
# 00:59:35
# 00:59:34
# 00:59:33
# 00:59:32
# 00:59:31
# 00:59:30
# 00:59:29
# 00:59:28
# 00:59:27
# 00:59:26
# 00:59:25
# 00:59:24
# 00:59:23
# 00:59:22
# 00:59:21
# 00:59:20
# 00:59:19
# 00:59:18
# 00:59:17
# 00:59:16
# 00:59:15
# 00:59:14
# 00:59:13
# 00:59:12
# 00:59:11
# 00:59:10
# 00:59:09
# 00:59:08
# 00:59:07
# 00:59:06
# 00:59:05
# 00:59:04
# 00:59:03
# 00:59:02
# 00:59:01
# 00:59:00
# 00:58:59
# 00:58:58
# 00:58:57
# 00:58:56
# 00:58:55
# 00:58:54
# 00:58:53
# 00:58:52
# 00:58:51
# 00:58:50
# 00:58:49
# 00:58:48
# 00:58:47
# 00:58:46
# 00:58:45
# 00:58:44
# 00:58:43
# 00:58:42
# 00:58:41
# 00:58:40
# 00:58:39
# 00:58:38
# 00:58:37
# 00:58:36
# 00:58:35
# ...

# %% [markdown]
# ## 7. Shopping cart program

# %%
Foods=[]
prices=[]

while True:
  food=input("Enter o food to buy (q to quit): ")
  if food=="q":
    break 
  else:
    price=float(input(f"Enter a price of a {food} : "))
    Foods.append(food)
    prices.append(price)

print("----Your Cart----")

for food in Foods:
  print(food)
# Out:
# ----Your Cart----
# momo
# noodles
# keema noodles
